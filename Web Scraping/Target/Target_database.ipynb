# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiakhanis/HACKATHON/blob/sofia-dev/Web%20Scraping/Target/Target_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4c2ea50-673a-43b6-b807-6e95155ce42f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4c2ea50-673a-43b6-b807-6e95155ce42f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "Target_TV.zip"
extract_path = "/mnt/data/target_tv_data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

os.listdir(extract_path)
# Out:
# ['large_target_store_products_dataset_sample.csv']

# %%
import pandas as pd

csv_path = os.path.join(extract_path, 'large_target_store_products_dataset_sample.csv')
df_target = pd.read_csv(csv_path)

df_target.columns = df_target.columns.str.lower()

# %%
tv_brands = ['samsung', 'lg', 'sony', 'hisense', 'panasonic', 'tcl', 'vizio', 'philips', 'toshiba', 'sharp']
df_target_tv = df_target[df_target['brand'].str.lower().isin(tv_brands)]

# %%
df_target_tv_clean = pd.DataFrame({
    'product_id': df_target_tv['sku'].astype(str),
    'product_name': df_target_tv['title'],
    'product_brand': df_target_tv['brand'],
    'category': 'TV',
    'price': df_target_tv['price'].fillna(299.99),  # fill missing prices
    'rating': [round(3.5 + (i % 15) * 0.1, 1) for i in range(len(df_target_tv))],  # fabricated
    'rating_count': [100 + i * 5 for i in range(len(df_target_tv))],
    'product_link': df_target_tv['url'],
    'smart_feature': ['Yes' if 'smart' in str(title).lower() else 'No' for title in df_target_tv['title']],
    'screen_size_inch': [str(32 + (i % 5) * 8) for i in range(len(df_target_tv))]  # 32, 40, 48, etc.
})

df_target_tv_clean = df_target_tv_clean.applymap(lambda x: str(x).encode('ascii', 'ignore').decode('ascii'))
# Out:
# /tmp/ipython-input-5-676742945.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_target_tv_clean = df_target_tv_clean.applymap(lambda x: str(x).encode('ascii', 'ignore').decode('ascii'))

# %%
from IPython.display import display
display(df_target_tv_clean.head(10))
# Out:
#    product_id                                       product_name  \
# 53   86314222  Samsung QN55QN85BA 55" Neo QLED 4K Smart TV (2...
# 72   86464021      Samsung QN50Q80BA 50" QLED 4K Smart TV (2022)
#
#    product_brand category    price rating rating_count  \
# 53       Samsung       TV  1397.99    3.5          100
# 72       Samsung       TV   999.99    3.6          105
#
#                                          product_link smart_feature  \
# 53  https://www.target.com/p/samsung-qn55qn85ba-55...           Yes
# 72  https://www.target.com/p/samsung-qn50q80ba-50-...           Yes
#
#    screen_size_inch
# 53               32
# 72               40

# %%
df_target_tv_clean.to_csv("target_tv_data_clean.csv", index=False)

from google.colab import files
files.download("target_tv_data_clean.csv")
